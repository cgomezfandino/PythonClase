# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
x = np.random.beta(1.0, 5.0, 1000)
y = np.random.normal(size=1000)

plt.figure(1)
plt.subplot(121)
plt.hist(x, bins= 10)
plt.subplot(122)
plt.hist(y,bins = 10)
# Out:
# (array([   3.,   23.,   67.,  169.,  254.,  210.,  157.,   85.,   22.,   10.]),
#  array([-3.20804576, -2.56976376, -1.93148177, -1.29319977, -0.65491778,
#         -0.01663578,  0.62164621,  1.25992821,  1.8982102 ,  2.5364922 ,
#          3.17477419]),
#  <a list of 10 Patch objects>)
