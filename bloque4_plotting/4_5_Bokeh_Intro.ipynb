# %% [markdown]
# # Gráficos para la Web con Bokeh

# %% [markdown]
# La biblioteca Bokeh (http://bokeh.pydata.org/) permite crear visualizaciones en Python, pero orientadas a su utilización en navegadores Web. El objetivo es conseguir:
# * visualizaciones interactivas al estilo de D3.js pero permitiendo su programación en Python
# * y dando soporte a streams de datos.
#
# Dado que un Notebook de Jupyter utiliza HTML para visualizar los resultados, Bokeh se integra con los Notebooks, como puede verse en los [ejemplos de bokeh](http://nbviewer.ipython.org/github/bokeh/bokeh-notebooks/blob/master/index.ipynb).
#
# Bokeh se inspira en la notación [Grammar of Graphics de Wilkinson](https://www.cs.uic.edu/~wilkinson/TheGrammarOfGraphics/GOG.html), al igual que el paquete [ggplot2](http://ggplot2.org/) de R, pero no son compatibles.

# %% [markdown]
# Para instalarlo, se puede utilizar pip o conda. Si tenemos Anaconda lo mejor es:
# ```
# conda install bokeh
# ```

# %% [markdown]
# Es fundamental entender que Bokeh es una interfaz que utiliza JavaScript en el navegador para la visualización, por lo que la programación se puede hacer en otros lenguajes que no son Python, por ejemplo en [R](https://hafen.github.io/rbokeh/#background).
# ![Bokeh](http://i1.wp.com/www.analyticsvidhya.com/wp-content/uploads/2015/08/Bokeh_Intro.png?zoom=2&resize=398%2C339)

# %% [markdown]
# ## Los tres niveles en Bokeh

# %% [markdown]
# Bokeh se puede utilizar en tres niveles:
# * low-level *bokeh.models* interface, máxima flexibilidad, pero hay que hacerlo todo parte a parte.
# * intermediate-level *bokeh.plotting* interface, centrado en la composición de glifos visuales (glyphs).
# * high-level *bokeh.charts* interface que simplifican la tarea de hacer visualizaciones o gráficos complejos, tomándolos de un catálogo pre-construido.

# %% [markdown]
# ## Bokeh como paleta de componentes

# %% [markdown]
# Bokeh puede utilizad como salidas diferentes formatos, entre ellos el del propio Notebook.

# %%
from bokeh.io import output_notebook, show
output_notebook() # Configura el Notebook como salida por defecto.
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bbc6c49f-faf6-4d8f-9186-c43931bdb767">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# Si utilizamos la interfaz **charts** solo tenemos que importar el tipo de gráfico que queramos.

# %% [markdown]
# Por ejemplo, vamos a cargar el dataset de películas de IMDB que está en el paquete ggplot2 de R (pueden consultarse [aquí](http://vincentarelbundock.github.io/Rdatasets/)).

# %%
#import statsmodels.api as sm
#imdb = sm.datasets.get_rdataset("movies", "ggplot2")
#print imdb.__doc__
import pandas as pd

data = pd.read_csv("movie_metadata.csv")
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                 40000.0  309404152.0         Action|Adventure|Fantasy
# 2                 11000.0  200074175.0        Action|Adventure|Thriller
# 3                 27000.0  448130642.0                  Action|Thriller
# 4                   131.0          NaN                      Documentary
#
#           ...          num_user_for_reviews language  country  content_rating  \
# 0         ...                        3054.0  English      USA           PG-13
# 1         ...                        1238.0  English      USA           PG-13
# 2         ...                         994.0  English       UK           PG-13
# 3         ...                        2701.0  English      USA           PG-13
# 4         ...                           NaN      NaN      NaN             NaN
#
#         budget  title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0  237000000.0      2009.0                  936.0        7.9          1.78
# 1  300000000.0      2007.0                 5000.0        7.1          2.35
# 2  245000000.0      2015.0                  393.0        6.8          2.35
# 3  250000000.0      2012.0                23000.0        8.5          2.35
# 4          NaN         NaN                   12.0        7.1           NaN
#
#   movie_facebook_likes
# 0                33000
# 1                    0
# 2                85000
# 3               164000
# 4                    0
#
# [5 rows x 28 columns]

# %%
from bokeh.charts import Scatter
samplesize = 200 # With the full dataset it becomes slow.
tools = "pan, box_zoom, reset, resize" # omit the annoying "wheel_zoom"

p = Scatter(data[:samplesize], x="duration", y="imdb_score", 
            color="color", tools=tools, legend="top_right")
show(p)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="0fb65917-f571-4737-93eb-d7d8aea9b520"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#0fb65917-f571-4737-93eb-d7d8aea9b520").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("
-48a6-8ca0-e3454b0ba147","type":"LinearAxis"},{"id":"ce4351dd-ec1d-4f36-a527-90fa204eb4d4","type":"LinearAxis"},{"id":"53e298db-582b-49a6-8f3e-7661e2c0b507","type":"Grid"},{"id":"78db01fe-4980-4f72-ba5b-85aedc9655f0","type":"Grid"}],"title":{"id":"b5cacac8-1928-464c-8759-3364bba801ce","type":"Title"},"tool_events":{"id":"05780da5-8158-4c1d-920a-f3d53 ...

# %% [markdown]
# Podemos ahora observar las valoraciones de acuerdo a la clasificación [MPAA](https://en.wikipedia.org/wiki/Motion_Picture_Association_of_America_film_rating_system). Pero podemos observar que hay muchos valores nulos, que tenemos que excluir del análisis.

# %%
import numpy as np
print np.unique(data["content_rating"])
print data.groupby("content_rating")["movie_title"].count()
# Out:
# [nan 'Approved' 'G' 'GP' 'M' 'NC-17' 'Not Rated' 'PG' 'PG-13' 'Passed' 'R'
#  'TV-14' 'TV-G' 'TV-MA' 'TV-PG' 'TV-Y' 'TV-Y7' 'Unrated' 'X']
# content_rating
# Approved       55
# G             112
# GP              6
# M               5
# NC-17           7
# Not Rated     116
# PG            701
# PG-13        1461
# Passed          9
# R            2118
# TV-14          30
# TV-G           10
# TV-MA          20
# TV-PG          13
# TV-Y            1
# TV-Y7           1
# Unrated        62
# X              13
# Name: movie_title, dtype: int64

# %%
from bokeh.charts import BoxPlot
b = BoxPlot(data.dropna(how="any", subset=["content_rating", "imdb_score"]), 
            values="imdb_score", label="content_rating", tools=tools)
show(b)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="1db5f496-5b4b-4503-acf2-6eb2289479ba"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#1db5f496-5b4b-4503-acf2-6eb2289479ba").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("1db5f496-5b4b-4503-acf2-6eb2289479ba");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '1db5f496-5b4b-4503-acf2-6eb2289479ba' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4e041cb3-1b4d-432a-9981-9c1ee8342b29":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"content_rating":"X"},{"content_rating":"X"},{"content_rating":"X"},{"content_rating":"X"}],"content_rating":["X","X","X","X"],"x0s":["X:0.5","X:0.65","X:0.5","X:0.65"],"x1s":["X:0.5","X:0.35","X:0.5","X:0.35"],"y0s":[4.0,4.0,7.5,7.9],"y1s":[5.5,4.0,7.9,7.9]}},"id":"b42a0cd7-c753-46ae-812d-b632184c9c52","type":"ColumnDataSource"},{"attributes":{},"id":"4f2803a9-d29c-460a-adfd-96870ff549d7","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{"chart_index":[{"content_rating":"TV-14"},{"content_rating":"TV-14"},{"content_rating":"TV-14"},{"content_rating":"TV-14"}],"content_rating":["TV-14","TV-14","TV-14","TV-14"],"x0s":["TV-14:0.5","TV-14:0.65","TV-14:0.5","TV-14:0.65"],"x1s":["TV-14:0.5","TV-14:0.35","TV-14:0.5","TV-14:0.35"],"y0s":[5.800000000000001,5.800000000000001,8.049999999999999,8.7],"y1s":[7.1499999999999995,5.800000000000001,8.7,8.7]}},"id":"7555b730-e4c9-4fcb-b4a9-56a48c169db3","type":"ColumnDataSource"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"content_rating":"M"}],"content_rating":["M"],"x_values":["M:0.5"],"y_values":[8.1]}},"id":"5961fa12-229c-4984-ad3f-02db6a39e245","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"482fdfb6-7f64-4e98-be0d-6531445a4cc7","subtype":"Chart","type":"Plot"}},"id":"e46e3042-0dc2-43fa-8ed9-753b9fdea7d2","type":"ResizeTool"},{"attributes":{"data_source":{"id":"744e5b10-2398-4608-9f3e-fe4c7e034ac7","type":"ColumnDataSource"},"glyph":{"id":"4a9b447a-4db9-4d05-ab8e-d976da649869","type":"Circle"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"28f42885-7b52-48be-9d5c-67abf04dde1c","type":"GlyphRenderer"},{"attributes":{"callback":null,"factors":["Approved","G","GP","M","NC-17","Not Rated","PG","PG-13","Passed","R","TV-14","TV-G","TV-MA","TV-PG","TV-Y","TV-Y7","Unrated","X"]},"id":"e9207b8c-cfd2-4cc5-bc9a-0b2a09a8c3be","type":"FactorRange"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"d0b18277-400b-462e-8703-31318052993f","type":"Rect"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"},{"content_rating":"PG-13"}],"content_rating":["PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13","PG-13"],"x_values":["PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5","PG-13:0.5"],"y_values":[3.3,2.4,2.7,3.4,2.8,2.7,2.3,1.9,3.1,3.1,3.3,3.0,3.1,2.8,3.3,2.1,3.1,2.0,2.3,2.1,3.0,3.3,3.4,2.2,3.4,3.3,3.2]}},"id":"744e5b10-2398-4608-9f3e-fe4c7e034ac7","type":"C ...

# %%
b = BoxPlot(data.dropna(how="any", subset=["content_rating", "budget"]), \
            values="budget", label="content_rating", tools=tools)
show(b)
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="91d00998-5fb0-482d-8c06-7d6a24240baa"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#91d00998-5fb0-482d-8c06-7d6a24240baa").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("91d00998-5fb0-482d-8c06-7d6a24240baa");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '91d00998-5fb0-482d-8c06-7d6a24240baa' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"4b710574-a868-4277-acf2-2b56e1719d40":{"roots":{"references":[{"attributes":{"data_source":{"id":"051285fa-5ef9-4e9e-8817-40739d76f874","type":"ColumnDataSource"},"glyph":{"id":"570f0936-d213-4b50-b987-8cf0299dbdda","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"e986a495-fa3d-4c0c-acbc-caf5b5e7d92a","type":"GlyphRenderer"},{"attributes":{"line_width":{"value":2},"x0":{"field":"x0s"},"x1":{"field":"x1s"},"y0":{"field":"y0s"},"y1":{"field":"y1s"}},"id":"b450f1d0-4011-4510-a50b-1b7f1fd1bcf4","type":"Segment"},{"attributes":{"data_source":{"id":"912f47dc-805f-45b5-97e6-d367ca905fed","type":"ColumnDataSource"},"glyph":{"id":"0df217cc-1273-45bc-8f50-d266d59cf64d","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"c1cd67c5-1521-4a09-8589-ef3a9be151f4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x0s","y0s","x1s","y1s"],"data":{

# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="9f12ef04-5d12-4975-b5dd-813bf554a1d2"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = "";
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force !== "") {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force !== "") {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         Bokeh.$("#9f12ef04-5d12-4975-b5dd-813bf554a1d2").text("BokehJS successfully loaded.");
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9f12ef04-5d12-4975-b5dd-813bf554a1d2");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9f12ef04-5d12-4975-b5dd-813bf554a1d2' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"cce29db9-100d-412f-b587-8526d472359d":{"roots":{"references":[{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"9cc5814e-2efc-41fa-a2ec-8ac86fa57c9b","type":"Rect"},{"attributes":{"data_source":{"id":"e2333489-6933-4074-8633-aa98f4306bb9","type":"ColumnDataSource"},"glyph":{"id":"e1a1070a-0769-4812-a107-9aa7efc50a95","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"5d22ceb1-99af-42ba-9973-1f35d6ab76c3","type":"GlyphRenderer"},{"attributes":{"data_source":{"id":"2e82d5c2-6841-46a7-88ca-061529c0a029","type":"ColumnDataSource"},"glyph":{"id":"499d5acd-f873-4fc8-b22e-a96b42d26a68","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"7870194f-ad93-43de-bb7e-b1c0d2e7bf14","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"f9e1f9cf-116f-4a43-b3bf-f5abe25724c7","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"2a7ad465-0b70-49a5-8eab-4ffd1f339028","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a9d89ab3-4e4e-4e4e-b38d-8326be11d28a","type":"Rect"},{"attributes":{"data_source":{"id":"7257950d-cfd4-4944-b6eb-1a5d1c7af22b","type":"ColumnDataSource"},"glyph":{"id":"05f2b40f-3781-4e80-9498-88f4741ec6f5","type":"Rect"},"hover_glyph":null,"nonselection_glyph":null,"selection_glyph":null},"id":"34676b7f-56c4-4960-b9c6-3bf5a92c2759","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["line_color","line_alpha","color","fill_alpha","height","width","y","x","label"],"data":{"chart_index":[{"content_rating":"Not Rated","title_year":2008.0}],"color":["#407ee7"],"content_rating":["Not Rated"],"fill_alpha":[0.8],"height":[4.0],"label":[{"content_rating":"Not Rated","title_year":2008.0}],"line_alpha":[1.0],"line_color":["white"],"title_year":[2008.0],"width":[0.8],"x":["2008.0"],"y":[215.0]}},"id":"bf53c0b7-9e27-4d4e-80cc-2c40dec5bbff","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"499d5acd-f873-4fc8-b22e-a96b42d26a68","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"73454f44-e258-43bf-b67b-507f1656244e","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"cc59c2ca-a402-444c-8996-2009002b4acc","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"776e5082-d94c-4176-a685-919b0b71b06f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color ...

# %% [markdown]
# ## Bokeh y Big Data

# %% [markdown]
# En lo visto hasta aquí, los datos están en memoria (DataFrame de pandas) y Bokeh los utiliza íntegramente, lo cual deja de ser práctico cuando hay muchos datos a mostrar en un solo gráfico.

# %% [markdown]
# Bokeh integra la posibilidad de utilizar [WebGL](http://bokeh.pydata.org/en/latest/docs/user_guide/webgl.html#userguide-webgl) para acelerar mediante la Graphics Processing Unit (GPU) el javascript generado. Esto simplemente aprovecha una característica presente en la mayoría de los navegadores modernos.

# %% [markdown]
# Otra posibilidad es utilizar un Servidor de Bokeh, de modo que los gráficos se actualizan en el servidor y los clientes JavaScript proporcionan una vista.
#
# ![Bokeh Server](http://bokeh.pydata.org/en/0.8.2/_images/bokeh_server.png)

# %% [markdown]
# Por último, Bokeh se puede combinar con proyectos como [Blaze](http://blaze.readthedocs.org/en/latest/index.html), una biblioteca que trata de proporcionar una interfaz de programación parecida a los DataFrames de pandas, pero actuando sobre conjuntos de datos grandes, que en ocasiones no se pueden tener en memoria.
#
# https://www.youtube.com/watch?v=mC2uEUyeNWQ
